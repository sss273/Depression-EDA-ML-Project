# %%
import pandas as pd
import numpy as np
data = pd.read_csv('desktop/myThesis/DATASET/train_split_Depression_AVEC2017.csv', delimiter = ',')
# data

# %%
from sklearn.model_selection import train_test_split

# %%
data
data = data.dropna() 
# to remove nan values
# data
# Out:
#      Participant_ID  PHQ8_Binary  PHQ8_Score  Gender  PHQ8_NoInterest  \
# 0               303            0           0       0                0
# 1               304            0           6       0                0
# 2               305            0           7       1                0
# 3               310            0           4       1                1
# 4               312            0           2       1                0
# 5               313            0           7       1                1
# 6               315            0           2       1                0
# 7               316            0           6       1                1
# 8               317            0           8       1                1
# 9               318            0           3       1                0
# 11              320            1          11       0                1
# 12              321            1          20       0                2
# ...

# %%
# ['Participant_ID', 'PHQ8_Binary', 'PHQ8_Score', 'Gender', 'PHQ8_NoInterest', 'PHQ8_Depressed', 'PHQ8_Sleep', 'PHQ8_Tired', 'PHQ8_Appetite', 'PHQ8_Failure', 'PHQ8_Concentrating', 'PHQ8_Moving']
X = data.drop(['Participant_ID','PHQ8_Score', 'PHQ8_Binary', 'Gender'], axis='columns')
# removing columns that will not be the features
# X.head()
# Out:
#    PHQ8_NoInterest  PHQ8_Depressed  PHQ8_Sleep  PHQ8_Tired  PHQ8_Appetite  \
# 0                0               0         0.0           0              0
# 1                0               1         1.0           2              2
# 2                0               1         1.0           2              2
# 3                1               1         0.0           0              0
# 4                0               0         1.0           1              0
#
#    PHQ8_Failure  PHQ8_Concentrating  PHQ8_Moving
# 0             0                   0            0
# 1             0                   0            0
# 2             1                   0            0
# 3             1                   1            0
# 4             0                   0            0

# %%
y = data.PHQ8_Binary
# specifying the target labels columns which is the y i.e. the label
# y.head()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
len(X_train)
# Out:
# 84

# %%
len(X_test)
# Out:
# 22

# %%
len(y_train)
# Out:
# 84

# %%
len(y_test)
# Out:
# 22

# %%
X.shape
# Out:
# (106, 8)

# %%
y.shape
# Out:
# (106,)

# %%
from sklearn.svm import SVC
model = SVC(kernel = 'linear')

# %%
model.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
model.score(X_test, y_test)
# Out:
# 1.0
